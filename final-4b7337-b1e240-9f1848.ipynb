# %% [markdown]
# ## 1. Data Loading
#
# This section imports the required libraries, defines the dataset path in Kaggle, and loads the main dataset files.
# It also reads the CSV file and checks the number of images, masks, and records to make sure the dataset is correctly connected and ready for cleaning.

# %%
# Import the required libraries for data loading, cleaning,  preprocessing, and training
import os                          # Used to manage files and folder paths
import cv2                         # Used to read and process images
import pandas as pd                # Used to read and inspect the CSV file
import matplotlib.pyplot as plt    # Used to display images
import xml.etree.ElementTree as ET # Used to read XML annotation files
from PIL import Image              # Used to check if images are valid or corrupted
import shutil                      # Used to copy images and label files
from sklearn.model_selection import train_test_split  # Used to split data into training and validation sets
# !pip install ultralytics
from ultralytics import YOLO
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.4.70-py3-none-any.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.13.0.92)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.16.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.10.0+cpu)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.25.0+cpu)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.35.2)
# Collecting nvidia-ml-py>=12.0.0 (from ultralytics)
#   Downloading nvidia_ml_py-13.610.43-py3-none-any.whl.metadata (9.7 kB)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics)
#   Downloading ultralytics_thop-2.0.20-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (26.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.35.2 in /usr/local/lib/python3.12/dist-packages (from polars>=0.20.0->ultralytics) (1.35.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2026.1.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.24.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2026.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Downloading ultralytics-8.4.70-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 21.4 MB/s eta 0:00:00
# Downloading nvidia_ml_py-13.610.43-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.2/53.2 kB 3.1 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.20-py3-none-any.whl (28 kB)
# Installing collected packages: nvidia-ml-py, ultralytics-thop, ultralytics
# Successfully installed nvidia-ml-py-13.610.43 ultralytics-8.4.70 ultralytics-thop-2.0.20
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# Define the dataset path in Kaggle and check the main dataset files

dataset_path = "/kaggle/input/datasets/trainingdatapro/parking-space-detection-dataset"
print("Dataset files:", os.listdir(dataset_path))
# Out:
# Dataset files: ['boxes', 'images', 'parking.csv', 'annotations.xml']

# %%
# Define the main file and folder locations inside the dataset

images_path = dataset_path + "/images"          # Folder containing original parking images
boxes_path = dataset_path + "/boxes"            # Folder containing mask/box images
csv_path = dataset_path + "/parking.csv"        # CSV file containing image and mask information
xml_path = dataset_path + "/annotations.xml"    # XML file containing parking space annotations

# %%
# Read the CSV file and display the first five rows to inspect the dataset records

df = pd.read_csv(csv_path)
df.head()
# Out:
#    id         image         mask
# 0   0  images/0.png  boxes/0.png
# 1   1  images/1.png  boxes/1.png
# 2   2  images/2.png  boxes/2.png
# 3   3  images/3.png  boxes/3.png
# 4   4  images/4.png  boxes/4.png

# %%
# Check the number of images, masks, and CSV records

print("Number of images:", len(os.listdir(images_path)))
print("Number of masks:", len(os.listdir(boxes_path)))
print("CSV rows:", len(df))
# Out:
# Number of images: 30
# Number of masks: 30
# CSV rows: 33

# %% [markdown]
# ## 2. Data Cleaning
# This section checks all parking images to make sure they are readable and not corrupted before using them for model training.

# %%
# Check all images to make sure they are readable and not corrupted before preprocessing

valid_images = []
corrupted_images = []

# Loop through each image and verify that it can be opened correctly
for img_name in os.listdir(images_path):
    img_path = os.path.join(images_path, img_name)

    try:
        img = Image.open(img_path)
        img.verify()
        valid_images.append(img_name)
    except Exception:
        corrupted_images.append(img_name)

# Print the cleaning results
print("Total images:", len(os.listdir(images_path)))
print("Valid images:", len(valid_images))
print("Corrupted images:", len(corrupted_images))
print("Corrupted files:", corrupted_images)
# Out:
# Total images: 30
# Valid images: 30
# Corrupted images: 0
# Corrupted files: []

# %% [markdown]
# ## 3. Data Preprocessing
#
# This section prepares the dataset for YOLO training. It reads the XML annotation file, converts polygon annotations into YOLO TXT label format, splits the images and labels into training and validation sets, and creates the data.yaml configuration file required by YOLO.

# %%
# Read the XML annotation file that contains parking space labels and coordinates

tree = ET.parse(xml_path)
root = tree.getroot()

# Print basic information about the XML file
print("Root tag:", root.tag)
print("Number of annotated images:", len(root.findall("image")))

# Display the attributes of the first annotated image to understand the XML structure
first_image = root.findall("image")[0]
print("First image attributes:", first_image.attrib)
# Out:
# Root tag: annotations
# Number of annotated images: 30
# First image attributes: {'id': '0', 'name': 'images/0.png', 'width': '1200', 'height': '621'}

# %%
# Convert XML polygon annotations into YOLO label format

output_labels_path = "/kaggle/working/yolo_labels"
os.makedirs(output_labels_path, exist_ok=True)

# Define class IDs for the two parking space classes
class_map = {
    "free_parking_space": 0,
    "not_free_parking_space": 1
}

# Loop through each image in the XML file and convert its annotations into YOLO labels
for image_tag in root.findall("image"):
    image_name = image_tag.attrib["name"]
    image_width = float(image_tag.attrib["width"])
    image_height = float(image_tag.attrib["height"])

    label_lines = []

    # Loop through each polygon annotation in the current image
    for polygon in image_tag.findall("polygon"):
        label = polygon.attrib["label"]

        if label not in class_map:
            continue

        class_id = class_map[label]
        points = polygon.attrib["points"].split(";")

        x_points = []
        y_points = []

        # Extract all x and y coordinates from the polygon points
        for point in points:
            x, y = point.split(",")
            x_points.append(float(x))
            y_points.append(float(y))

        # Convert polygon coordinates into a rectangular bounding box
        x_min = min(x_points)
        y_min = min(y_points)
        x_max = max(x_points)
        y_max = max(y_points)

        # Normalize bounding box values to match YOLO format
        x_center = ((x_min + x_max) / 2) / image_width
        y_center = ((y_min + y_max) / 2) / image_height
        box_width = (x_max - x_min) / image_width
        box_height = (y_max - y_min) / image_height

        # Save the annotation line in YOLO format: class x_center y_center width height
        label_lines.append(
            f"{class_id} {x_center} {y_center} {box_width} {box_height}"
        )

    # Create a TXT label file with the same name as the image
    txt_name = os.path.splitext(os.path.basename(image_name))[0] + ".txt"
    txt_path = os.path.join(output_labels_path, txt_name)

    # Write all YOLO labels for the current image into the TXT file
    with open(txt_path, "w") as f:
        f.write("\n".join(label_lines))

print("YOLO labels created successfully!")
print("Number of label files:", len(os.listdir(output_labels_path)))
# Out:
# YOLO labels created successfully!
# Number of label files: 30

# %%
# Split images and labels into training and validation sets

yolo_dataset_path = "/kaggle/working/parking_yolo_dataset"

folders = [
    "images/train", "images/val",
    "labels/train", "labels/val"
]

# Create YOLO folder structure
for folder in folders:
    os.makedirs(os.path.join(yolo_dataset_path, folder), exist_ok=True)

# Split image files into 80% training and 20% validation
image_files = sorted(os.listdir(images_path))

train_files, val_files = train_test_split(
    image_files,
    test_size=0.2,
    random_state=42
)

# Copy images and their matching labels to the correct folder
def copy_files(file_list, split_name):
    for img_name in file_list:
        label_name = os.path.splitext(img_name)[0] + ".txt"

        shutil.copy(
            os.path.join(images_path, img_name),
            os.path.join(yolo_dataset_path, "images", split_name, img_name)
        )

        shutil.copy(
            os.path.join(output_labels_path, label_name),
            os.path.join(yolo_dataset_path, "labels", split_name, label_name)
        )

copy_files(train_files, "train")
copy_files(val_files, "val")

print("Training images:", len(train_files))
print("Validation images:", len(val_files))
# Out:
# Training images: 24
# Validation images: 6

# %%
# Create a data.yaml file that tells YOLO where the training and validation images are located,
# and defines the number and names of the parking space classes.

yaml_content = """
train: /kaggle/working/parking_yolo_dataset/images/train
val: /kaggle/working/parking_yolo_dataset/images/val

nc: 2
names:
  0: free_parking_space
  1: not_free_parking_space
"""

# Save the data.yaml file inside the prepared YOLO dataset folder
yaml_path = "/kaggle/working/parking_yolo_dataset/data.yaml"

with open(yaml_path, "w") as f:
    f.write(yaml_content)

print("data.yaml created successfully!")
print("YAML file path:", yaml_path)
# Out:
# data.yaml created successfully!
# YAML file path: /kaggle/working/parking_yolo_dataset/data.yaml

# %%
# Verify that the YOLO dataset folders were created correctly

print("Main YOLO dataset folders:", os.listdir("/kaggle/working/parking_yolo_dataset"))
print("Image folders:", os.listdir("/kaggle/working/parking_yolo_dataset/images"))
print("Label folders:", os.listdir("/kaggle/working/parking_yolo_dataset/labels"))
# Out:
# Main YOLO dataset folders: ['labels', 'data.yaml', 'images']
# Image folders: ['train', 'val']
# Label folders: ['train', 'val']

# %% [markdown]
# ## 4. Model Training (Baseline Fine-Tuning)

# %%
# Train YOLOv8 nano model for 20 epochs as a baseline experiment

model_20 = YOLO("yolov8n.pt")

results_20 = model_20.train(
    data="/kaggle/working/parking_yolo_dataset/data.yaml",
    epochs=20,      # Baseline training rounds
    imgsz=640,      # Resize input images to 640x640
    batch=8,        # Number of images processed together
    name="parking_baseline_yolov8n_20epochs"
)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 68.6MB/s 0.1s
# Ultralytics 8.4.70 🚀 Python-3.12.12 torch-2.10.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/parking_yolo_dataset/data.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=20, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=parking_baseline_yolov8n_20epochs, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/detect/parking_baseline_yolov8n_20epochs, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 16.4MB/s 0.0s
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751702  ultralytics.nn.modules.head.Detect           [2, 16, None, [64, 128, 256]]
# Model summary: 130 layers, 3,011,238 parameters, 3,011,222 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2657.1±1078.2 MB/s, size: 259.4 KB)
# train: Scanning /kaggle/working/parking_yolo_dataset/labels/train... 24 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 24/24 932.6it/s 0.0s
# train: New cache created: /kaggle/working/parking_yolo_dataset/labels/train.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2241.2±404.6 MB/s, size: 145.7 KB)
# val: Scanning /kaggle/working/parking_yolo_dataset/labels/val... 6 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 6/6 820.1it/s 0.0s
# val: New cache created: /kaggle/working/parking_yolo_dataset/labels/val.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Plotting labels to /kaggle/working/runs/detect/parking_baseline_yolov8n_20epochs/labels.jpg...
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to /kaggle/working/runs/detect/parking_baseline_yolov8n_20epochs
# Starting training for 20 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/20         0G      2.132      3.503      1.784        448        640: 100% ━━━━━━━━━━━━ 3/3 5.0s/it 15.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.5s/it 1.5s
#                    all          6        232     0.0395      0.273     0.0298    0.00932
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/20         0G      1.872      3.486      1.597        436        640: 100% ━━━━━━━━━━━━ 3/3 4.2s/it 12.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.4s/it 1.4s
#                    all          6        232     0.0454      0.314     0.0351     0.0129
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/20         0G      1.663      3.314      1.418        318        640: 100% ━━━━━━━━━━━━ 3/3 4.2s/it 12.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.4s/it 1.4s
#                    all          6        232     0.0509      0.358     0.0444     0.0189
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/20         0G      1.451      3.039      1.364        297        640: 100% ━━━━━━━━━━━━ 3/3 4.1s/it 12.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.4s/it 1.4s
#                    all          6        232     0.0719      0.514     0.0899     0.0407
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/20         0G      1.402       3.07       1.26        474        640: 100% ━━━━━━━━━━━━ 3/3 4.3s/it 12.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.4s/it 1.4s
#                    all          6        232     0.0753      0.546      0.103     0.0487
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/20         0G      1.273       2.75      1.186        341        640: 100% ━━━━━━━━━━━━ 3/3 4.1s/it 12.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.4s/it 1.4s
#                    all          6        232     0.0732      0.553      0.166     0.0917
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/20         0G      1.175        2.5      1.121        295        640: 100% ━━━━━━━━━━━━ 3/3 3.9s/it 11.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.4s/it 1.4s
#                    all          6        232     0.0731      0.547      0.194       0.11
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/20         0G       1.19      2.263       1.12        361        640: 100% ━━━━━━━━━━━━ 3/3 4.0s/it 11.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.4s/it 1.4s
#                    all          6        232     0.0721      0.536      0.211      0.126
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/20         0G      1.155      2.179      1.104        329        640: 100% ━━━━━━━━━━━━ 3/3 3.9s/it 11.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.4s/it 1.4s
#                    all          6        232     0.0726      0.533      0.249      0.164
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/20         0G      1.077      2.147      1.059        374        640: 100% ━━━━━━━━━━━━ 3/3 4.1s/it 12.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.4s/it 1.4s
#                    all          6        232     0.0808      0.497      0.289      0.191
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/20         0G     0.9824       1.67      1.003        233        640: 100% ━━━━━━━━━━━━ 3/3 4.0s/it 11.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.4s/it 1.4s
#                    all          6        232      0.896       0.14       0.31      0.204
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/20         0G      1.078      1.604      1.029        207        640: 100% ━━━━━━━━━━━━ 3/3 3.8s/it 11.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.4s/it 1.4s
#                    all          6        232      0.904      0.147      0.333      0.224
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/20         0G     0.9739      1.574      1.008        219        640: 100% ━━━━━━━━━━━━ 3/3 3.8s/it 11.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.3s/it 1.3s
#                    all          6        232      0.932      0.157      0.367      0.247
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/20         0G     0.9288      1.491     0.9976        166        640: 100% ━━━━━━━━━━━━ 3/3 3.8s/it 11.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.4s/it 1.4s
#                    all          6        232       0.93      0.195      0.386      0.258
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/20         0G      0.997      1.429     0.9781        208        640: 100% ━━━━━━━━━━━━ 3/3 3.9s/it 11.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.4s/it 1.4s
#                    all          6        232       0.93      0.195      0.386      0.258
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/20         0G     0.8999      1.387     0.9665        218        640: 100% ━━━━━━━━━━━━ 3/3 3.8s/it 11.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.3s/it 1.3s
#                    all          6        232      0.901      0.227      0.399      0.273
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/20         0G     0.9265      1.385     0.9726        183        640: 100% ━━━━━━━━━━━━ 3/3 3.8s/it 11.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.4s/it 1.4s
#                    all          6        232      0.904      0.266      0.415      0.287
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/20         0G     0.8952      1.302     0.9773        225        640: 100% ━━━━━━━━━━━━ 3/3 3.8s/it 11.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.4s/it 1.4s
#                    all          6        232      0.904      0.266      0.415      0.287
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/20         0G     0.8355      1.334     0.9647        244        640: 100% ━━━━━━━━━━━━ 3/3 3.9s/it 11.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.4s/it 1.4s
#                    all          6        232      0.903      0.289      0.438       0.31
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/20         0G     0.8786      1.264     0.9406        214        640: 100% ━━━━━━━━━━━━ 3/3 3.9s/it 11.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.4s/it 1.4s
#                    all          6        232      0.443      0.296       0.46      0.328
#
# 20 epochs completed in 0.076 hours.
# Optimizer stripped from /kaggle/working/runs/detect/parking_baseline_yolov8n_20epochs/weights/last.pt, 6.2MB
# Optimizer stripped from /kaggle/working/runs/detect/parking_baseline_yolov8n_20epochs/weights/best.pt, 6.2MB
#
# Validating /kaggle/working/runs/detect/parking_baseline_yolov8n_20epochs/weights/best.pt...
# Ultralytics 8.4.70 🚀 Python-3.12.12 torch-2.10.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# Model summary (fused): 73 layers, 3,006,038 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.1s/it 1.1s
#                    all          6        232        0.4      0.294      0.459      0.328
#     free_parking_space          6         89          0          0      0.113     0.0863
# not_free_parking_space          6        143        0.8      0.588      0.804       0.57
# Speed: 1.3ms preprocess, 140.9ms inference, 0.0ms loss, 25.2ms postprocess per image
# Results saved to /kaggle/working/runs/detect/parking_baseline_yolov8n_20epochs

# %%
# Load a pre-trained YOLOv8 nano model
model = YOLO("yolov8n.pt")

# Train the YOLO model on our parking dataset
results = model.train(
    # Path to the YAML file that tells YOLO where the training and validation images are
    data="/kaggle/working/parking_yolo_dataset/data.yaml",
    epochs=50, # Number of training rounds
    imgsz=640, # Resize all input images to 640x640 during training
    batch=8,# Number of images processed together in one training step
    # YOLO will save the results under this folder name
    name="parking_baseline_yolov8n_50epochs" 
)
# Out:
# Ultralytics 8.4.70 🚀 Python-3.12.12 torch-2.10.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/parking_yolo_dataset/data.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=parking_baseline_yolov8n_50epochs, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/detect/parking_baseline_yolov8n_50epochs, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751702  ultralytics.nn.modules.head.Detect           [2, 16, None, [64, 128, 256]]
# Model summary: 130 layers, 3,011,238 parameters, 3,011,222 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1575.7±494.0 MB/s, size: 215.2 KB)
# train: Scanning /kaggle/working/parking_yolo_dataset/labels/train.cache... 24 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 24/24 9.2Mit/s 0.0s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2218.2±687.0 MB/s, size: 198.6 KB)
# val: Scanning /kaggle/working/parking_yolo_dataset/labels/val.cache... 6 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 6/6 1.7Mit/s 0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Plotting labels to /kaggle/working/runs/detect/parking_baseline_yolov8n_50epochs/labels.jpg...
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to /kaggle/working/runs/detect/parking_baseline_yolov8n_50epochs
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50         0G      2.111      3.519      1.835        436        640: 100% ━━━━━━━━━━━━ 3/3 4.3s/it 12.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.5s/it 1.5s
#                    all          6        232     0.0341      0.231     0.0236    0.00849
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50         0G       1.84      3.537      1.594        416        640: 100% ━━━━━━━━━━━━ 3/3 4.2s/it 12.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.5s/it 1.5s
#                    all          6        232      0.039      0.261     0.0285     0.0113
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50         0G      1.641      3.249      1.426        361        640: 100% ━━━━━━━━━━━━ 3/3 4.1s/it 12.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.4s/it 1.4s
#                    all          6        232     0.0466      0.328     0.0352     0.0152
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50         0G      1.527      3.239      1.343        592        640: 100% ━━━━━━━━━━━━ 3/3 4.1s/it 12.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.4s/it 1.4s
#                    all          6        232     0.0531      0.381     0.0487     0.0253
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50         0G      1.303      2.999      1.231        325        640: 100% ━━━━━━━━━━━━ 3/3 4.2s/it 12.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.4s/it 1.4s
#                    all          6        232     0.0673      0.493     0.0755     0.0405
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50         0G      1.222      2.704      1.161        390        640: 100% ━━━━━━━━━━━━ 3/3 4.0s/it 12.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.4s/it 1.4s
#                    all          6        232     0.0666      0.488      0.104     0.0557
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50         0G      1.219      2.366      1.163        316        640: 100% ━━━━━━━━━━━━ 3/3 4.1s/it 12.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.4s/it 1.4s
#                    all          6        232     0.0662      0.484      0.137     0.0788
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50         0G      1.147      2.242      1.078        409        640: 100% ━━━━━━━━━━━━ 3/3 4.1s/it 12.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.4s/it 1.4s
#                    all          6        232     0.0757       0.54      0.229      0.141
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50         0G      1.138       2.18      1.089        422        640: 100% ━━━━━━━━━━━━ 3/3 4.1s/it 12.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.4s/it 1.4s
#                    all          6        232     0.0763      0.537       0.28      0.177
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50         0G      1.042      1.923      1.069        411        640: 100% ━━━━━━━━━━━━ 3/3 4.0s/it 12.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.4s/it 1.4s
#                    all          6        232      0.806      0.294      0.322        0.2
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50         0G     0.9949      1.914      1.022        403        640: 100% ━━━━━━━━━━━━ 3/3 4.2s/it 12.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.3s/it 1.3s
#                    all          6        232      0.902      0.203       0.34      0.211
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50         0G     0.9734      1.821      1.013        400        640: 100% ━━━━━━━━━━━━ 3/3 4.1s/it 12.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.3s/it 1.3s
#                    all          6        232       0.98      0.167      0.366      0.225
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50         0G     0.9968      1.719      1.021        463        640: 100% ━━━━━━━━━━━━ 3/3 4.1s/it 12.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.3s/it 1.3s
#                    all          6        232      0.953      0.238      0.387       0.25
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50         0G     0.8993      1.529     0.9935        359        640: 100% ━━━━━━━━━━━━ 3/3 4.1s/it 12.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.4s/it 1.4s
#                    all          6        232      0.912      0.276      0.389      0.266
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50         0G     0.8969      1.398     0.9845        419        640: 100% ━━━━━━━━━━━━ 3/3 4.0s/it 12.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.3s/it 1.3s
#                    all          6        232      0.912      0.276      0.389      0.266
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50         0G     0.8631      1.418     0.9791        469        640: 100% ━━━━━━━━━━━━ 3/3 4.2s/it 12.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.4s/it 1.4s
#                    all          6        232      0.372       0.29      0.394      0.272
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50         0G     0.8177      1.319     0.9947        255        640: 100% ━━━━━━━━━━━━ 3/3 4.0s/it 12.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.3s/it 1.3s
#                    all          6        232      0.481      0.341      0.419      0.312
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50         0G     0.8318      1.193     0.9608        410        640: 100% ━━━━━━━━━━━━ 3/3 4.2s/it 12.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.3s/it 1.3s
#                    all          6        232      0.481      0.341      0.419      0.312
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50         0G      0.899      1.206     0.9967        343        640: 100% ━━━━━━━━━━━━ 3/3 4.1s/it 12.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.3s/it 1.3s
#                    all          6        232      0.518      0.427       0.45      0.339
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50         0G      0.814      1.081     0.9796        364        640: 100% ━━━━━━━━━━━━ 3/3 4.1s/it 12.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.3s/it 1.3s
#                    all          6        232      0.567      0.527      0.506      0.382
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50         0G      0.802     0.9918     0.9813        396        640: 100% ━━━━━━━━━━━━ 3/3 4.0s/it 12.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.3s/it 1.3s
#                    all          6        232      0.567      0.527      0.506      0.382
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50         0G     0.8921      1.125      1.029        354        640: 100% ━━━━━━━━━━━━ 3/3 4.0s/it 12.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.3s/it 1.3s
#                    all          6        232      0.658      0.529      0.566      0.443
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50         0G     0.7787     0.9691     0.9789        300        640: 100% ━━━━━━━━━━━━ 3/3 4.1s/it 12.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.3s/it 1.3s
#                    all          6        232      0.658      0.529      0.566      0.443
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50         0G     0.8869     0.9947     0.9946        517        640: 100% ━━━━━━━━━━━━ 3/3 4.1s/it 12.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.3s/it 1.3s
#                    all          6        232      0.741      0.504      0.618      0.488
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50         0G     0.7565     0.8958     0.9771        354        640: 100% ━━━━━━━━━━━━ 3/3 4.0s/it 12.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.3s/it 1.3s
#                    all          6        232      0.741      0.504      0.618      0.488
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50         0G     0.7835     0.9193      1.002        351        640: 100% ━━━━━━━━━━━━ 3/3 3.9s/it 11.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.3s/it 1.3s
#                    all          6        232      0.721      0.642       0.69      0.521
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50         0G     0.7827     0.8986     0.9793        391        640: 100% ━━━━━━━━━━━━ 3/3 4.0s/it 11.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.3s/it 1.3s
#                    all          6        232      0.721      0.642       0.69      0.521
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50         0G     0.8766     0.9341      1.037        339        640: 100% ━━━━━━━━━━━━ 3/3 4.0s/it 11.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.3s/it 1.3s
#                    all          6        232       0.88      0.655      0.775      0.568
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50         0G     0.7614     0.9206     0.9585        441        640: 100% ━━━━━━━━━━━━ 3/3 4.2s/it 12.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.3s/it 1.3s
#                    all          6        232       0.88      0.655      0.775      0.568
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50         0G     0.7637     0.8507     0.9986        377        640: 100% ━━━━━━━━━━━━ 3/3 3.9s/it 11.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.3s/it 1.3s
#                    all          6        232       0.88      0.655      0.775      0.568
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50         0G     0.7702     0.8616     0.9625        484        640: 100% ━━━━━━━━━━━━ 3/3 4.1s/it 12.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.3s/it 1.3s
#                    all          6        232      0.908      0.683       0.82      0.605
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50         0G     0.7139      0.775     0.9543        334        640: 100% ━━━━━━━━━━━━ 3/3 3.9s/it 11.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.4s/it 1.4s
#                    all          6        232      0.908      0.683       0.82      0.605
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50         0G     0.7108     0.7628     0.9325        437        640: 100% ━━━━━━━━━━━━ 3/3 4.2s/it 12.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.3s/it 1.3s
#                    all          6        232      0.908       0.72       0.87      0.645
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50         0G     0.6791     0.7567     0.9447        441        640: 100% ━━━━━━━━━━━━ 3/3 4.0s/it 12.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.3s/it 1.3s
#                    all          6        232      0.908       0.72       0.87      0.645
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50         0G     0.7624     0.7775      0.965        467        640: 100% ━━━━━━━━━━━━ 3/3 4.1s/it 12.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.3s/it 1.3s
#                    all          6        232      0.908       0.72       0.87      0.645
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50         0G     0.7464     0.7917     0.9679        395        640: 100% ━━━━━━━━━━━━ 3/3 4.1s/it 12.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.3s/it 1.3s
#                    all          6        232      0.881      0.785      0.887      0.667
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50         0G     0.6871     0.7665     0.9545        447        640: 100% ━━━━━━━━━━━━ 3/3 4.1s/it 12.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.4s/it 1.4s
#                    all          6        232      0.881      0.785      0.887      0.667
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50         0G     0.6699     0.7549     0.9203        534        640: 100% ━━━━━━━━━━━━ 3/3 4.1s/it 12.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.3s/it 1.3s
#                    all          6        232      0.881      0.785      0.887      0.667
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50         0G     0.6819     0.8344     0.9354        229        640: 100% ━━━━━━━━━━━━ 3/3 4.0s/it 12.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.3s/it 1.3s
#                    all          6        232      0.891      0.791      0.888      0.685
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50         0G     0.6946     0.7733     0.9365        373        640: 100% ━━━━━━━━━━━━ 3/3 4.2s/it 12.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.4s/it 1.4s
#                    all          6        232      0.891      0.791      0.888      0.685
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50         0G     0.7344      1.023     0.9381        202        640: 100% ━━━━━━━━━━━━ 3/3 3.9s/it 11.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.4s/it 1.4s
#                    all          6        232      0.886        0.8      0.894      0.694
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50         0G     0.6311     0.8744      0.913        184        640: 100% ━━━━━━━━━━━━ 3/3 3.8s/it 11.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.3s/it 1.3s
#                    all          6        232      0.886        0.8      0.894      0.694
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50         0G     0.6573     0.8997     0.9196        202        640: 100% ━━━━━━━━━━━━ 3/3 3.8s/it 11.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.3s/it 1.3s
#                    all          6        232      0.886        0.8      0.894      0.694
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50         0G     0.6456     0.9099     0.9275        222        640: 100% ━━━━━━━━━━━━ 3/3 3.8s/it 11.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.3s/it 1.3s
#                    all          6        232      0.847      0.841      0.901      0.695
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50         0G     0.6548     0.9271     0.9224        236        640: 100% ━━━━━━━━━━━━ 3/3 3.8s/it 11.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.4s/it 1.4s
#                    all          6        232      0.847      0.841      0.901      0.695
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50         0G     0.6925     0.9325     0.9319        217        640: 100% ━━━━━━━━━━━━ 3/3 3.8s/it 11.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.4s/it 1.4s
#                    all          6        232      0.847      0.841      0.901      0.695
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50         0G     0.6441     0.9132     0.9289        218        640: 100% ━━━━━━━━━━━━ 3/3 3.8s/it 11.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.4s/it 1.4s
#                    all          6        232      0.832      0.839      0.906      0.691
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50         0G     0.6075     0.8625     0.8862        231        640: 100% ━━━━━━━━━━━━ 3/3 3.9s/it 11.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.4s/it 1.4s
#                    all          6        232      0.832      0.839      0.906      0.691
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50         0G     0.6122     0.8497     0.9005        231        640: 100% ━━━━━━━━━━━━ 3/3 3.8s/it 11.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.4s/it 1.4s
#                    all          6        232      0.861      0.838      0.909      0.694
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50         0G     0.6544     0.8783      0.926        204        640: 100% ━━━━━━━━━━━━ 3/3 3.8s/it 11.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.4s/it 1.4s
#                    all          6        232      0.861      0.838      0.909      0.694
#
# 50 epochs completed in 0.191 hours.
# Optimizer stripped from /kaggle/working/runs/detect/parking_baseline_yolov8n_50epochs/weights/last.pt, 6.2MB
# Optimizer stripped from /kaggle/working/runs/detect/parking_baseline_yolov8n_50epochs/weights/best.pt, 6.2MB
#
# Validating /kaggle/working/runs/detect/parking_baseline_yolov8n_50epochs/weights/best.pt...
# Ultralytics 8.4.70 🚀 Python-3.12.12 torch-2.10.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# Model summary (fused): 73 layers, 3,006,038 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.0s/it 1.0s
#                    all          6        232      0.849       0.84      0.901      0.695
#     free_parking_space          6         89      0.854      0.723      0.831      0.629
# not_free_parking_space          6        143      0.843      0.958      0.971      0.762
# Speed: 1.3ms preprocess, 139.0ms inference, 0.0ms loss, 19.1ms postprocess per image
# Results saved to /kaggle/working/runs/detect/parking_baseline_yolov8n_50epochs

# %% [markdown]
# ## 5. Model Evaluation

# %%
# Evaluate the 20-epoch YOLO model on the validation dataset
model_20_eval = YOLO("/kaggle/working/runs/detect/parking_baseline_yolov8n_20epochs/weights/best.pt")

metrics_20 = model_20_eval.val(
    data="/kaggle/working/parking_yolo_dataset/data.yaml"
)

# Print the evaluation scores for the 20-epoch model
print("20 Epochs Results")
print("Precision:", metrics_20.box.mp)      # Precision measures how many detected parking spaces were correctly predicted
print("Recall:", metrics_20.box.mr)         # Recall measures how many real parking spaces were successfully detected
print("mAP50:", metrics_20.box.map50)       # Measures overall object detection accuracy at IoU 0.50
print("mAP50-95:", metrics_20.box.map)      # Measures detection performance with stricter evaluation
# Out:
# Ultralytics 8.4.70 🚀 Python-3.12.12 torch-2.10.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# Model summary (fused): 73 layers, 3,006,038 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2548.5±662.2 MB/s, size: 145.7 KB)
# val: Scanning /kaggle/working/parking_yolo_dataset/labels/val.cache... 6 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 6/6 1.6Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.0s/it 1.0s
#                    all          6        232        0.4      0.294      0.459      0.328
#     free_parking_space          6         89          0          0      0.113     0.0863
# not_free_parking_space          6        143        0.8      0.588      0.804       0.57
# Speed: 1.0ms preprocess, 137.4ms inference, 0.0ms loss, 25.3ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val
# 20 Epochs Results
# Precision: 0.40002542998825563
# Recall: 0.2938005447117167
# mAP50: 0.4586542112536732
# mAP50-95: 0.3278821336852172

# %%
# Evaluate the trained YOLO model on the validation dataset
metrics = model.val()

# Print the Precision score
print("Precision:", metrics.box.mp)# Precision measures how many detected parking spaces were predicted correctly
print("Recall:", metrics.box.mr)# Recall measures how many real parking spaces were successfully detected by the model
print("mAP50:", metrics.box.map50)# Measures overall object detection accuracy
print("mAP50-95:", metrics.box.map)# Measures detection performance with stricter evaluation
# Out:
# Ultralytics 8.4.70 🚀 Python-3.12.12 torch-2.10.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# Model summary (fused): 73 layers, 3,006,038 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2777.3±677.8 MB/s, size: 198.1 KB)
# val: Scanning /kaggle/working/parking_yolo_dataset/labels/val.cache... 6 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 6/6 1.8Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.0s/it 1.0s
#                    all          6        232      0.849       0.84      0.901      0.695
#     free_parking_space          6         89      0.854      0.723      0.831      0.629
# not_free_parking_space          6        143      0.843      0.958      0.971      0.762
# Speed: 1.0ms preprocess, 135.6ms inference, 0.0ms loss, 19.9ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val-2
# Precision: 0.8486989872559765
# Recall: 0.8403840230528126
# mAP50: 0.9007619009466137
# mAP50-95: 0.6953733508276314

# %%
# Create a comparison table between the 20-epoch and 50-epoch models

comparison_table = {
    "Model": ["YOLOv8n Baseline", "YOLOv8n Improved"],
    "Epochs": [20, 50],
    "Precision": [metrics_20.box.mp, metrics.box.mp],
    "Recall": [metrics_20.box.mr, metrics.box.mr],
    "mAP50": [metrics_20.box.map50, metrics.box.map50],
    "mAP50-95": [metrics_20.box.map, metrics.box.map]
}

df_comparison = pd.DataFrame(comparison_table)
df_comparison
# Out:
#               Model  Epochs  Precision    Recall     mAP50  mAP50-95
# 0  YOLOv8n Baseline      20   0.400025  0.293801  0.458654  0.327882
# 1  YOLOv8n Improved      50   0.848699  0.840384  0.900762  0.695373

# %% [markdown]
# ## 6. Training Results Visualization

# %%
# Path to the training results image generated by YOLO
results_path = "/kaggle/working/runs/detect/parking_baseline_yolov8n_50epochs/results.png"

results_img = cv2.imread(results_path)# Read the results image
# Convert image colors from BGR to RGB for correct display
results_img = cv2.cvtColor(results_img, cv2.COLOR_BGR2RGB)

# Display the training results image
plt.figure(figsize=(15,10))
plt.imshow(results_img)
plt.axis("off")
plt.show()

# %% [markdown]
# ## 7.Prediction & Testing

# %%
# "best.pt" contains the weights of the model that achieved the best performance during training
model = YOLO("/kaggle/working/runs/detect/parking_baseline_yolov8n_50epochs/weights/best.pt")

# Select one image from the validation dataset for testing
# Here we selected the third image using index [2]
image_path = "/kaggle/working/parking_yolo_dataset/images/val/" + os.listdir("/kaggle/working/parking_yolo_dataset/images/val")[2]

# Prediction
results = model.predict(source=image_path, conf=0.25)# conf=0.25 means the model will display detections with confidence greater than 25%

# Draw the prediction results
result_img = results[0].plot()
# Convert image colors from BGR to RGB for correct display in Matplotlib
result_img = cv2.cvtColor(result_img, cv2.COLOR_BGR2RGB)

# Display the predicted image
plt.figure(figsize=(15,10))
plt.imshow(result_img)
plt.axis("off")
plt.show()
# Out:
# image 1/1 /kaggle/working/parking_yolo_dataset/images/val/31.png: 384x640 13 free_parking_spaces, 11 not_free_parking_spaces, 110.2ms
# Speed: 3.1ms preprocess, 110.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)

# %% [markdown]
# # Load/Stress + Scalability

# %%
import time
import os
from ultralytics import YOLO

# Load the best trained model
model = YOLO("/kaggle/working/runs/detect/parking_baseline_yolov8n_50epochs/weights/best.pt")

# Validation images folder
val_images_path = "/kaggle/working/parking_yolo_dataset/images/val"
image_files = os.listdir(val_images_path)

prediction_times = []

# Run prediction on multiple images
for image_name in image_files:
    image_path = os.path.join(val_images_path, image_name)

    start_time = time.time()
    model.predict(source=image_path, conf=0.25, verbose=False)
    end_time = time.time()

    prediction_times.append(end_time - start_time)

# Calculate performance results
average_time = sum(prediction_times) / len(prediction_times)
fastest_time = min(prediction_times)
slowest_time = max(prediction_times)

print("Number of tested images:", len(image_files))
print("Average prediction time:", average_time, "seconds")
print("Fastest prediction time:", fastest_time, "seconds")
print("Slowest prediction time:", slowest_time, "seconds")
# Out:
# Number of tested images: 6
# Average prediction time: 0.13114964962005615 seconds
# Fastest prediction time: 0.10248279571533203 seconds
# Slowest prediction time: 0.16867733001708984 seconds

# %%
import os

print("Train Images:", len(os.listdir("/kaggle/working/parking_yolo_dataset/images/train")))
print("Validation Images:", len(os.listdir("/kaggle/working/parking_yolo_dataset/images/val")))
# Out:
# Train Images: 24
# Validation Images: 6

# %%
import time

total_runs = 20
all_times = []

for run in range(total_runs):
    start_time = time.time()

    for image_name in image_files:
        image_path = os.path.join(val_images_path, image_name)
        model.predict(source=image_path, conf=0.25, verbose=False)

    end_time = time.time()
    all_times.append(end_time - start_time)

print("Stress Test Runs:", total_runs)
print("Average Run Time:", sum(all_times)/len(all_times), "seconds")
print("Minimum Run Time:", min(all_times), "seconds")
print("Maximum Run Time:", max(all_times), "seconds")
print("Total Predictions:", total_runs * len(image_files))
# Out:
# Stress Test Runs: 20
# Average Run Time: 0.6623592615127564 seconds
# Minimum Run Time: 0.6488380432128906 seconds
# Maximum Run Time: 0.6949634552001953 seconds
# Total Predictions: 120

# %% [markdown]
# # Monitoring + Logging

# %%
import os
import time
import pandas as pd
from ultralytics import YOLO

# Load the trained YOLO model
model_path = "/kaggle/working/runs/detect/parking_baseline_yolov8n_50epochs/weights/best.pt"
model = YOLO(model_path)

# Validation images folder
test_images_dir = "/kaggle/working/parking_yolo_dataset/images/val"

# Output log file
log_file = "/kaggle/working/monitoring_log.csv"

# Threshold for prediction time warning
TIME_THRESHOLD = 0.20

logs = []

# Get all validation images
image_files = [
    f for f in os.listdir(test_images_dir)
    if f.lower().endswith((".jpg", ".jpeg", ".png"))
]

# Run prediction and collect monitoring logs
for image_name in image_files:
    image_path = os.path.join(test_images_dir, image_name)

    start_time = time.time()
    results = model.predict(source=image_path, conf=0.25, verbose=False)
    prediction_time = time.time() - start_time

    number_of_detections = len(results[0].boxes)

    if prediction_time > TIME_THRESHOLD:
        status = "Warning: High prediction time"
    else:
        status = "OK"

    logs.append({
        "image_name": image_name,
        "prediction_time_seconds": round(prediction_time, 4),
        "number_of_detections": number_of_detections,
        "status": status
    })

# Save logs into CSV file
log_df = pd.DataFrame(logs)
log_df.to_csv(log_file, index=False)

print("Monitoring log saved successfully!")
display(log_df)


# Monitoring Summary

summary = {
    "total_images_tested": len(log_df),
    "average_prediction_time_seconds": round(log_df["prediction_time_seconds"].mean(), 4),
    "fastest_prediction_time_seconds": round(log_df["prediction_time_seconds"].min(), 4),
    "slowest_prediction_time_seconds": round(log_df["prediction_time_seconds"].max(), 4),
    "total_detections": int(log_df["number_of_detections"].sum()),
    "warnings_count": int((log_df["status"] != "OK").sum())
}

summary_df = pd.DataFrame([summary])

print("Monitoring Summary:")
display(summary_df)
# Out:
# Monitoring log saved successfully!
#   image_name  prediction_time_seconds  number_of_detections status
# 0     26.png                   0.1472                    83     OK
# 1     24.png                   0.0938                    36     OK
# 2     31.png                   0.1085                    24     OK
# 3     18.png                   0.1209                    34     OK
# 4     17.png                   0.1518                    22     OK
# 5      6.png                   0.1030                    97     OK
# Monitoring Summary:
#    total_images_tested  average_prediction_time_seconds  \
# 0                    6                           0.1209
#
#    fastest_prediction_time_seconds  slowest_prediction_time_seconds  \
# 0                           0.0938                           0.1518
#
#    total_detections  warnings_count
# 0               296               0

# %%
# Function to check if an image exists and is readable
def load_image_safely(image_path):
    try:
        # Attempt to read the image using OpenCV
        img = cv2.imread(image_path)

        # Check if the image was loaded successfully (img will be None if not)
        if img is None:
            raise FileNotFoundError(f"Image not found or corrupted at {image_path}")

        print(f"Successfully loaded image: {image_path}")
        return img
    except Exception as e:
        print(f"Error loading image {image_path}: {e}")
        return None

# --- Test Cases for Image Loading ---

# Define the validation images directory
val_images_dir = "/kaggle/working/parking_yolo_dataset/images/val/"

# Test with an existing image
if os.path.exists(val_images_dir) and os.listdir(val_images_dir):
    existing_image_path = os.path.join(val_images_dir, os.listdir(val_images_dir)[0])
    loaded_img = load_image_safely(existing_image_path)
else:
    print(f"Validation image directory not found or is empty: {val_images_dir}. Cannot test existing image loading.")

# Test with a non-existent image path
non_existent_image_path = "/kaggle/working/parking_yolo_dataset/images/val/non_existent_image_test.png"
loaded_img_fail = load_image_safely(non_existent_image_path)
# Out:
# Successfully loaded image: /kaggle/working/parking_yolo_dataset/images/val/26.png
# Error loading image /kaggle/working/parking_yolo_dataset/images/val/non_existent_image_test.png: Image not found or corrupted at /kaggle/working/parking_yolo_dataset/images/val/non_existent_image_test.png
# [ WARN:0@1039.600] global loadsave.cpp:278 findDecoder imread_('/kaggle/working/parking_yolo_dataset/images/val/non_existent_image_test.png'): can't open/read file: check file path/integrity

# %%
from ultralytics import YOLO # Import YOLO inside the function to ensure it's available

# Function to safely load a YOLO model
def load_model_safely(model_path):
    try:
        # Attempt to load the YOLO model
        model = YOLO(model_path)
        print(f"Successfully loaded model from: {model_path}")
        return model
    except Exception as e:
        print(f"Error loading model from {model_path}: {e}")
        return None

# --- Test Cases for Model Loading ---

# Define the path to the best trained model (from previous sections)
best_model_path = "/kaggle/working/runs/detect/parking_baseline_yolov8n_50epochs/weights/best.pt"

# Test with an existing model path
if os.path.exists(best_model_path):
    loaded_yolo_model = load_model_safely(best_model_path)
else:
    print(f"Trained model not found at: {best_model_path}. Cannot test existing model loading.")

# Test with a non-existent model path
non_existent_model_path = "/kaggle/working/non_existent_model.pt"
loaded_yolo_model_fail = load_model_safely(non_existent_model_path)
# Out:
# Successfully loaded model from: /kaggle/working/runs/detect/parking_baseline_yolov8n_50epochs/weights/best.pt
# Error loading model from /kaggle/working/non_existent_model.pt: [Errno 2] No such file or directory: '/kaggle/working/non_existent_model.pt'

# %%
# Define the path to the best trained model
best_model_path = "/kaggle/working/runs/detect/parking_baseline_yolov8n_50epochs/weights/best.pt"

# Safely load the YOLO model
model = load_model_safely(best_model_path)

# Proceed with predictions only if the model was loaded successfully
if model is not None:
    # Define the validation images directory
    val_images_dir = "/kaggle/working/parking_yolo_dataset/images/val/"

    # Get a list of validation image files
    validation_image_files = os.listdir(val_images_dir)

    if validation_image_files:
        # Select one image from the validation dataset for testing (e.g., the first one)
        image_to_test = validation_image_files[0]
        image_path = os.path.join(val_images_dir, image_to_test)

        # Safely load the image
        loaded_img = load_image_safely(image_path)

        if loaded_img is not None:
            print(f"\nAttempting prediction on {image_to_test}...")
            try:
                # Perform prediction
                results = model.predict(source=image_path, conf=0.25)

                # Draw the prediction results
                result_img = results[0].plot()
                # Convert image colors from BGR to RGB for correct display in Matplotlib
                result_img = cv2.cvtColor(result_img, cv2.COLOR_BGR2RGB)

                # Display the predicted image
                plt.figure(figsize=(15, 10))
                plt.imshow(result_img)
                plt.title(f"Prediction for {image_to_test}")
                plt.axis("off")
                plt.show()
            except Exception as e:
                print(f"Error during prediction for {image_to_test}: {e}")
        else:
            print(f"Skipping prediction because image {image_to_test} could not be loaded safely.")
    else:
        print("No images found in the validation directory for testing.")
else:
    print("Skipping predictions because the model could not be loaded safely.")
# Out:
# Successfully loaded model from: /kaggle/working/runs/detect/parking_baseline_yolov8n_50epochs/weights/best.pt
# Successfully loaded image: /kaggle/working/parking_yolo_dataset/images/val/26.png
#
# Attempting prediction on 26.png...
#
# image 1/1 /kaggle/working/parking_yolo_dataset/images/val/26.png: 448x640 32 free_parking_spaces, 51 not_free_parking_spaces, 106.5ms
# Speed: 3.3ms preprocess, 106.5ms inference, 1.6ms postprocess per image at shape (1, 3, 448, 640)
